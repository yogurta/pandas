# %%
import pandas

# %%
titanic = pandas.read_csv('static/titanic.csv', index_col=None)
titanic
# Out:
#       Unnamed: 0                                              Name PClass  \
# 0              1                      Allen, Miss Elisabeth Walton    1st
# 1              2                       Allison, Miss Helen Loraine    1st
# 2              3               Allison, Mr Hudson Joshua Creighton    1st
# 3              4     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st
# 4              5                     Allison, Master Hudson Trevor    1st
# 5              6                                Anderson, Mr Harry    1st
# 6              7                  Andrews, Miss Kornelia Theodosia    1st
# 7              8                            Andrews, Mr Thomas, jr    1st
# 8              9      Appleton, Mrs Edward Dale (Charlotte Lamson)    1st
# 9             10                            Artagaveytia, Mr Ramon    1st
# 10            11                         Astor, Colonel John Jacob    1st
# 11            12  Astor, Mrs John Jacob (Madeleine Talmadge Force)    1st
# ...

# %%
titanic.describe()
# Celkem víme o 1313 pasažérech Titanicu.
# Out:
#         Unnamed: 0         Age     Survived      SexCode
# count  1313.000000  756.000000  1313.000000  1313.000000
# mean    657.000000   30.397989     0.342727     0.351866
# std     379.174762   14.259049     0.474802     0.477734
# min       1.000000    0.170000     0.000000     0.000000
# 25%     329.000000   21.000000     0.000000     0.000000
# 50%     657.000000   28.000000     0.000000     0.000000
# 75%     985.000000   39.000000     1.000000     1.000000
# max    1313.000000   71.000000     1.000000     1.000000

# %%
titanic['Survived']
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# 5       1
# 6       1
# 7       0
# 8       1
# 9       0
# 10      0
# 11      1
# 12      1
# 13      1
# 14      0
# 15      1
# 16      0
# 17      0
# 18      1
# 19      1
# 20      1
# 21      0
# 22      1
# 23      1
# 24      1
# 25      0
# 26      1
# 27      1
# 28      1
# 29      0
#        ..
# 1283    0
# 1284    0
# 1285    0
# 1286    0
# 1287    0
# 1288    0
# 1289    1
# 1290    0
# 1291    0
# 1292    0
# 1293    1
# 1294    0
# 1295    0
# 1296    0
# 1297    0
# 1298    0
# 1299    0
# 1300    0
# 1301    0
# 1302    1
# 1303    0
# 1304    1
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# 1309    0
# 1310    0
# 1311    0
# 1312    0
# Name: Survived, Length: 1313, dtype: int64

# %%
{1: 'žije', 0: 'nežije'}.get(1)
# Out:
# 'žije'

# %%
titanic.groupby('Survived').count()
# Přežilo 450 osob
# Out:
#           Unnamed: 0  Name  PClass  Age  Sex  SexCode
# Survived
# 0                863   863     863  443  863      863
# 1                450   450     450  313  450      450

# %%
titanic['Survived'].value_counts()
# Pro kontrolu, přežilo opravdu 450 osob
# Out:
# 0    863
# 1    450
# Name: Survived, dtype: int64

# %%
titanic['Survived'].value_counts(normalize=True) *100
#Přežilo 34.27%
# Out:
# 0    65.727342
# 1    34.272658
# Name: Survived, dtype: float64

# %%
titanic.groupby('SexCode').sum()
# Out:
#          Unnamed: 0       Age  Survived
# SexCode
# 0            588823  14514.71       142
# 1            273818   8466.17       308

# %%
titanic.sort_index()
# Out:
#       Unnamed: 0                                              Name PClass  \
# 0              1                      Allen, Miss Elisabeth Walton    1st
# 1              2                       Allison, Miss Helen Loraine    1st
# 2              3               Allison, Mr Hudson Joshua Creighton    1st
# 3              4     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st
# 4              5                     Allison, Master Hudson Trevor    1st
# 5              6                                Anderson, Mr Harry    1st
# 6              7                  Andrews, Miss Kornelia Theodosia    1st
# 7              8                            Andrews, Mr Thomas, jr    1st
# 8              9      Appleton, Mrs Edward Dale (Charlotte Lamson)    1st
# 9             10                            Artagaveytia, Mr Ramon    1st
# 10            11                         Astor, Colonel John Jacob    1st
# 11            12  Astor, Mrs John Jacob (Madeleine Talmadge Force)    1st
# ...

# %%
titanic[Survived == 1]
# Out:
#       Unnamed: 0                                               Name PClass  \
# 0              1                       Allen, Miss Elisabeth Walton    1st
# 4              5                      Allison, Master Hudson Trevor    1st
# 5              6                                 Anderson, Mr Harry    1st
# 6              7                   Andrews, Miss Kornelia Theodosia    1st
# 8              9       Appleton, Mrs Edward Dale (Charlotte Lamson)    1st
# 11            12   Astor, Mrs John Jacob (Madeleine Talmadge Force)    1st
# 12            13                       Aubert, Mrs Leontine Pauline    1st
# 13            14                           Barkworth, Mr Algernon H    1st
# 15            16     Baxter, Mrs James (Helene DeLaudeniere Chaput)    1st
# 18            19                       Beckwith, Mr Richard Leonard    1st
# 19            20    Beckwith, Mrs Richard Leonard (Sallie Monypeny)    1st
# ...

# %%
Survived = titanic['Survived']
Survived
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# 5       1
# 6       1
# 7       0
# 8       1
# 9       0
# 10      0
# 11      1
# 12      1
# 13      1
# 14      0
# 15      1
# 16      0
# 17      0
# 18      1
# 19      1
# 20      1
# 21      0
# 22      1
# 23      1
# 24      1
# 25      0
# 26      1
# 27      1
# 28      1
# 29      0
#        ..
# 1283    0
# 1284    0
# 1285    0
# 1286    0
# 1287    0
# 1288    0
# 1289    1
# 1290    0
# 1291    0
# 1292    0
# 1293    1
# 1294    0
# 1295    0
# 1296    0
# 1297    0
# 1298    0
# 1299    0
# 1300    0
# 1301    0
# 1302    1
# 1303    0
# 1304    1
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# 1309    0
# 1310    0
# 1311    0
# 1312    0
# Name: Survived, Length: 1313, dtype: int64

# %%
pandas.crosstab(titanic.Sex,titanic.Survived) # kolik % žen přežilo
# Out:
# Survived    0    1
# Sex
# female    154  308
# male      709  142

# %%
pandas.crosstab(titanic.Sex,titanic.Survived, normalize = 'columns')*100
# Přežilo 68.4% žen a 31.55% mužů
# Out:
# Survived          0          1
# Sex
# female    17.844728  68.444444
# male      82.155272  31.555556

# %%
pandas.crosstab(titanic.Survived,titanic.PClass, margins=True)
# Nastoupilo na loď 322 pasažérů 1. třídy, 279 pasažérů 2. třídy a 711 pasažérů 3. třídy.
# Přežilo 193 pasažérů 1. třídy, 119 pasažérů 2. třídy a 138 pasažérů 3. třídy
# Out:
# PClass    *  1st  2nd  3rd   All
# Survived
# 0         1  129  160  573   863
# 1         0  193  119  138   450
# All       1  322  279  711  1313

# %%
pandas.crosstab(titanic.Survived,titanic.PClass, margins=True, normalize ='columns')*100
#Přežilo tedy 59.94% z 1. třídy, 42.65% z 2. třídy a 19.40% z 3. třídy
# Out:
# PClass        *        1st       2nd        3rd        All
# Survived
# 0         100.0  40.062112  57.34767  80.590717  65.727342
# 1           0.0  59.937888  42.65233  19.409283  34.272658

# %%
titanic['SexCode'].value_counts()
# Out:
# 0    851
# 1    462
# Name: SexCode, dtype: int64

# %%
titanic['Age'].dropna().hist(color='k', alpha=0.5, bins=10)

# %%
titanic.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x108c1d7b8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108bab2b0>]], dtype=object)

# %%
titanic.Age.plot()

# %%
titanic['PClass'].value_counts()
# Out:
# 3rd    711
# 1st    322
# 2nd    279
# *        1
# Name: PClass, dtype: int64

# %%
pandas.crosstab(titanic.PClass,titanic.Age.mean())#.plot(kind='bar')
# Out:
# col_0   30.397989
# PClass
# *               1
# 1st           322
# 2nd           279
# 3rd           711

# %%
titanic.groupby(['PClass','Age']).mean()
# Out:
#                Unnamed: 0  Survived   SexCode
# PClass Age
# 1st    0.92      5.000000  1.000000  0.000000
#        2.00      2.000000  0.000000  1.000000
#        4.00     87.000000  1.000000  0.000000
#        6.00    243.000000  1.000000  0.000000
#        11.00    51.000000  1.000000  0.000000
#        13.00   222.000000  1.000000  0.000000
#        14.00    50.000000  1.000000  1.000000
#        15.00   170.000000  1.000000  1.000000
#        16.00   153.000000  1.000000  1.000000
#        17.00   183.666667  1.000000  0.666667
#        18.00   229.750000  0.750000  0.750000
#        19.00    90.200000  0.800000  0.800000
#        20.00   283.000000  1.000000  1.000000
#        21.00   216.400000  0.800000  0.600000
#        22.00   130.400000  0.800000  0.800000
#        23.00   150.600000  1.000000  0.800000
#        24.00   145.800000  0.600000  0.400000
#        25.00    44.250000  0.500000  0.250000
#        26.00    43.000000  1.000000  0.500000
# ...

# %%
titanic.groupby('PClass',as_index=False)['Age'].mean().dropna() #Zjišťuje, jak na sobě závisí třída a věk pasažéra
# Průměrný věk pasažérů v 1. třídě byl 39.67 let, v 2. třídě 28.3 let a ve 3. třídě 25.21 let.
# Out:
#   PClass        Age
# 1    1st  39.667788
# 2    2nd  28.300142
# 3    3rd  25.208585

# %%
titanic.groupby('PClass',as_index=False)['Age'].mean().dropna().plot(kind='bar')
# Viz graf

# %%
pandas.crosstab(titanic.PClass,titanic.Age).plot(kind='bar')
# Toto nám nic něřekne, ale pro představu..
